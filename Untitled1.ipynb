# %% [markdown]
# # ===== SETUP AND INSTALLATIONS =====
# # Run this cell first in Colab

# %%
# AI/ML Image Classification Project for Google Colab
# This project demonstrates image classification using CNNs on the CIFAR-10 dataset


# !pip install -q tensorflow matplotlib numpy scikit-learn

# %% [markdown]
# # ===== IMPORTS =====

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

print(f"TensorFlow Version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
# Out:
# TensorFlow Version: 2.19.0
# GPU Available: []

# %% [markdown]
# # ===== DATA LOADING AND PREPROCESSING =====

# %%
print("\n=== Loading CIFAR-10 Dataset ===")
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# === Loading CIFAR-10 Dataset ===
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %% [markdown]
# # Class names

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Image shape: {X_train.shape[1:]}")
# Out:
# Training samples: 50000
# Test samples: 10000
# Image shape: (32, 32, 3)

# %% [markdown]
# # Normalize pixel values to [0, 1]

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %% [markdown]
# # Convert labels to categorical

# %%
y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# %% [markdown]
# # ===== DATA VISUALIZATION =====

# %%
def visualize_samples(X, y, class_names, n=10):
    """Visualize random samples from dataset"""
    plt.figure(figsize=(15, 3))
    indices = np.random.choice(len(X), n, replace=False)

    for i, idx in enumerate(indices):
        plt.subplot(2, 5, i + 1)
        plt.imshow(X[idx])
        plt.title(class_names[y[idx][0]])
        plt.axis('off')

    plt.tight_layout()
    plt.show()

print("\n=== Sample Images from Dataset ===")
visualize_samples(X_train, y_train, class_names)
# Out:
# === Sample Images from Dataset ===

# %% [markdown]
# # ===== MODEL ARCHITECTURE =====

# %%
print("\n=== Building CNN Model ===")

model = models.Sequential([
    # First Convolutional Block
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Second Convolutional Block
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Third Convolutional Block
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Dense Layers
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

model.summary()
# Out:
# === Building CNN Model ===
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ...

# %% [markdown]
# # ===== MODEL COMPILATION =====

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)







# ===== INTERACTIVE PREDICTION FUNCTION =====
def predict_image(img_index):
    """Predict a single image from test set"""
    img = X_test[img_index]
    img_expanded = np.expand_dims(img, axis=0)

    prediction = model.predict(img_expanded, verbose=0)
    predicted_class = np.argmax(prediction)
    confidence = np.max(prediction) * 100

    plt.figure(figsize=(10, 4))

    # Show image
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title(f"True: {class_names[y_test[img_index][0]]}")
    plt.axis('off')

    # Show prediction probabilities
    plt.subplot(1, 2, 2)
    plt.barh(class_names, prediction[0])
    plt.xlabel('Probability')
    plt.title(f'Predicted: {class_names[predicted_class]} ({confidence:.1f}%)')
    plt.tight_layout()
    plt.show()

# Try predicting a random image
print("\n=== Single Image Prediction ===")
random_idx = np.random.randint(0, len(X_test))
predict_image(random_idx)

print("\n=== Project Complete! ===")
print("You can now:")
print("1. Train the model with different architectures")
print("2. Experiment with hyperparameters")
print("3. Try different datasets")
print("4. Use predict_image(index) to test specific images")
# Out:
# === Single Image Prediction ===
# === Project Complete! ===
# You can now:
# 1. Train the model with different architectures
# 2. Experiment with hyperparameters
# 3. Try different datasets
# 4. Use predict_image(index) to test specific images

# %% [markdown]
# # ===== DATA AUGMENTATION =====

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(X_train)

# ===== TRAINING =====
print("\n=== Training Model ===")
# Out:
# === Training Model ===

# %% [markdown]
# # Callbacks

# %%
early_stop = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6
)

# %% [markdown]
# # Train the model

# %%
history = model.fit(
    datagen.flow(X_train, y_train_cat, batch_size=64),
    epochs=50,
    validation_data=(X_test, y_test_cat),
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 459s 579ms/step - accuracy: 0.3458 - loss: 2.0445 - val_accuracy: 0.4933 - val_loss: 1.4775 - learning_rate: 0.0010
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 446s 570ms/step - accuracy: 0.5587 - loss: 1.2368 - val_accuracy: 0.5662 - val_loss: 1.4358 - learning_rate: 0.0010
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 501s 569ms/step - accuracy: 0.6329 - loss: 1.0335 - val_accuracy: 0.6832 - val_loss: 0.9015 - learning_rate: 0.0010
# Epoch 4/50
# ...

# %% [markdown]
# # ===== TRAINING HISTORY VISUALIZATION =====

# %%
def plot_history(history):
    """Plot training and validation metrics"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    # Accuracy
    ax1.plot(history.history['accuracy'], label='Train Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Val Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Loss
    ax2.plot(history.history['loss'], label='Train Loss')
    ax2.plot(history.history['val_loss'], label='Val Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

print("\n=== Training History ===")
plot_history(history)
# Out:
# === Training History ===

# %% [markdown]
# # ===== MODEL EVALUATION =====

# %%
print("\n=== Evaluating Model ===")
test_loss, test_acc = model.evaluate(X_test, y_test_cat, verbose=0)
print(f"Test Accuracy: {test_acc*100:.2f}%")
print(f"Test Loss: {test_loss:.4f}")

# Predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = y_test.flatten()

# Classification Report
print("\n=== Classification Report ===")
print(classification_report(y_true, y_pred_classes, target_names=class_names))

# ===== CONFUSION MATRIX =====
def plot_confusion_matrix(y_true, y_pred, class_names):
    """Plot confusion matrix"""
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.xticks(rotation=45)
    plt.yticks(rotation=45)
    plt.tight_layout()
    plt.show()

print("\n=== Confusion Matrix ===")
plot_confusion_matrix(y_true, y_pred_classes, class_names)
# Out:
# === Evaluating Model ===
# Test Accuracy: 88.06%
# Test Loss: 0.3580
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 63ms/step
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#     airplane       0.88      0.90      0.89      1000
#   automobile       0.91      0.96      0.94      1000
#         bird       0.86      0.84      0.85      1000
#          cat       0.84      0.69      0.76      1000
#         deer       0.85      0.89      0.87      1000
#          dog       0.86      0.80      0.83      1000
#         frog       0.89      0.94      0.91      1000
#        horse       0.86      0.94      0.90      1000
#         ship       0.93      0.92      0.93      1000
#        truck       0.91      0.94      0.92      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
#
#
# === Confusion Matrix ===

# %% [markdown]
# # ===== PREDICTION VISUALIZATION =====

# %%
def visualize_predictions(X, y_true, y_pred, class_names, n=10):
    """Visualize model predictions"""
    plt.figure(figsize=(15, 6))
    indices = np.random.choice(len(X), n, replace=False)

    for i, idx in enumerate(indices):
        plt.subplot(2, 5, i + 1)
        plt.imshow(X[idx])

        true_label = class_names[y_true[idx]]
        pred_label = class_names[y_pred[idx]]
        confidence = np.max(y_pred[idx]) * 100

        color = 'green' if y_true[idx] == y_pred[idx] else 'red'
        plt.title(f"True: {true_label}\nPred: {pred_label}\n({confidence:.1f}%)",
                 color=color, fontsize=9)
        plt.axis('off')

    plt.tight_layout()
    plt.show()

print("\n=== Sample Predictions ===")
visualize_predictions(X_test, y_true, y_pred_classes, class_names)

# ===== SAVE MODEL =====
print("\n=== Saving Model ===")
model.save('cifar10_classifier.h5')
print("Model saved as 'cifar10_classifier.h5'")
# Out:
# === Sample Predictions ===
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === Saving Model ===
# Model saved as 'cifar10_classifier.h5'

# %% [markdown]
# # ===== INTERACTIVE PREDICTION FUNCTION =====

# %%
def predict_image(img_index):
    """Predict a single image from test set"""
    img = X_test[img_index]
    img_expanded = np.expand_dims(img, axis=0)

    prediction = model.predict(img_expanded, verbose=0)
    predicted_class = np.argmax(prediction)
    confidence = np.max(prediction) * 100

    plt.figure(figsize=(10, 4))

    # Show image
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title(f"True: {class_names[y_test[img_index][0]]}")
    plt.axis('off')

    # Show prediction probabilities
    plt.subplot(1, 2, 2)
    plt.barh(class_names, prediction[0])
    plt.xlabel('Probability')
    plt.title(f'Predicted: {class_names[predicted_class]} ({confidence:.1f}%)')
    plt.tight_layout()
    plt.show()

# Try predicting a random image
print("\n=== Single Image Prediction ===")
random_idx = np.random.randint(0, len(X_test))
predict_image(random_idx)

print("\n=== Project Complete! ===")
print("You can now:")
print("1. Train the model with different architectures")
print("2. Experiment with hyperparameters")
print("3. Try different datasets")
print("4. Use predict_image(index) to test specific images")
# Out:
# === Single Image Prediction ===
# === Project Complete! ===
# You can now:
# 1. Train the model with different architectures
# 2. Experiment with hyperparameters
# 3. Try different datasets
# 4. Use predict_image(index) to test specific images
